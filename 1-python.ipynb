# %% [markdown]
# ### Introduction

# %%
name = 'chandru'

# %%
print(name)
# Out:
# chandru

# %%
input("Enter your name: ")
# Out:
# Enter your name:  Chandru
# 'Chandru'

# %%
print("Hello World")
# Out:
# Hello World

# %%
'''
Int(19), float(2.5), str("sweety"), list[1,2,3,4], dict{'name':'Chandru'}, set{'chandru',45,4.3}, tuple(1,2,3,4), booleans(True,False)
'''
# Out:
# '\nInt(19), float(2.5), str("sweety"), list[1,2,3,4], dict{\'name\':\'Chandru\'}, set{\'chandru\',45,4.3}, tuple(1,2,3,4), booleans(True,False)\n'

# %% [markdown]
# ### Numbers

# %%
1 + 2
# Out:
# 3

# %%
4* 6
# Out:
# 24

# %%
4/2
# Out:
# 2.0

# %%
6-9
# Out:
# -3

# %% [markdown]
# ### Modulo or Mod Operator

# %%
4/5
# Out:
# 0.8

# %%
3/2
# Out:
# 1.5

# %%
3%2
# Out:
# 1

# %%
50 % 2
# Out:
# 0

# %%
2 ** 3
# Out:
# 8

# %%
2**2
# Out:
# 4

# %% [markdown]
# ### Variables

# %%
my_dogs = 3

# %%
print(my_dogs)
# Out:
# 3

# %%
my_dogs
# Out:
# 3

# %%
my_frds = ['Loki','Kadhir']

# %%
my_frds
# Out:
# ['Loki', 'Kadhir']

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a + 10
# Out:
# 15

# %%
a = 10

# %%
a = a + a

# %%
a
# Out:
# 20

# %%
type(a)
# Out:
# int

# %%
type(my_dogs)
# Out:
# int

# %%
type(my_frds)
# Out:
# list

# %%
my_income = 100

tax = 0.1

my_taxes = my_income * tax

print(my_taxes)
# Out:
# 10.0

# %% [markdown]
# ### Strings

# %%
'hello'
# Out:
# 'hello'

# %%
"hello"
# Out:
# 'hello'

# %% [markdown]
# ## Slicing and Indexing

# %%
ver = "Hello"

# %%
ver[0]
# Out:
# 'H'

# %%
ver[1]
# Out:
# 'e'

# %%
ver[3]
# Out:
# 'l'

# %%
ver[-1]
# Out:
# 'o'

# %%
sent = 'this is also a string'

# %%
sent[:]
# Out:
# 'this is also a string'

# %%
sent[1:5]
# Out:
# 'his '

# %%
"I'm a person"
# Out:
# "I'm a person"

# %%
"chandru"
# Out:
# 'chandru'

# %%
print("Chandru")
# Out:
# Chandru

# %%
print("Chandru\nKathiravan")
# Out:
# Chandru
# Kathiravan

# %%
print("Chandru \t Kathiravan")
# Out:
# Chandru 	 Kathiravan

# %%
 len(sent)
# Out:
# 21

# %%
my_str = "Hello World"

# %%
my_str
# Out:
# 'Hello World'

# %%
print(my_str)
# Out:
# Hello World

# %%
my_str[0]
# Out:
# 'H'

# %%
my_str[7]
# Out:
# 'o'

# %%
my_str[9]
# Out:
# 'l'

# %%
my_str[-2]
# Out:
# 'l'

# %%
my_str
# Out:
# 'Hello World'

# %%
my_str[:]
# Out:
# 'Hello World'

# %%
my_str[0:5]
# Out:
# 'Hello'

# %%
my_str[0:4]
# Out:
# 'Hell'

# %%
my_str[3:8]
# Out:
# 'lo Wo'

# %%
my_str[::]
# Out:
# 'Hello World'

# %%
my_str[::2]
# Out:
# 'HloWrd'

# %%
my_str[::3]
# Out:
# 'HlWl'

# %%
my_str[::-1]
# Out:
# 'dlroW olleH'

# %%
name = "Sweety"

# %%
name[0] = 'K'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 name[0] = 'K'
#
# TypeError: 'str' object does not support item assignment

# %%
name[1:]
# Out:
# 'weety'

# %%
last_letters = name[1:]

# %%
'K' + last_letters
# Out:
# 'Kweety'

# %%
x = 'K' + last_letters

# %%
print(x)
# Out:
# Kweety

# %%
letter = 'md'
letter * 10
# Out:
# 'mdmdmdmdmdmdmdmdmdmd'

# %%
'2'+'3'
# Out:
# '23'

# %% [markdown]
# ### string functions

# %%
y = 'Hello World'

# %%
y.capitalize()
# Out:
# 'Hello world'

# %%
y.upper()
# Out:
# 'HELLO WORLD'

# %%
y.lower()
# Out:
# 'hello world'

# %%
y.title()
# Out:
# 'Hello World'

# %%
y.split()
# Out:
# ['Hello', 'World']

# %%
z = "Hi-Iam-Chandru"

# %%
z.split('-')
# Out:
# ['Hi', 'Iam', 'Chandru']

# %% [markdown]
# ### print formatting

# %%
my_name = 'Chandru'

# %%
print("Hello "+my_name)
# Out:
# Hello Chandru

# %%
print('this is a string {}'.format('Inserted'))
# Out:
# this is a string Inserted

# %%
print(my_name,'{} {} {}'.format('Friends','Family','Joy'))
# Out:
# Chandru Friends Family Joy

# %%
print(my_name,'{2} {1} {0}'.format('Friends','Family','Joy'))
# Out:
# Chandru Joy Family Friends

# %%
print('the {f} {b} {q}'.format(f ='fox',b='brown',q='quick'))
# Out:
# the fox brown quick

# %%
result = 100/77

# %%
print(result)
# Out:
# 1.2987012987012987

# %%
print("the result is {:.3f}".format(result))
# Out:
# the result is 1.299

# %%
print("the result is {:1.3f}".format(result))
# Out:
# the result is 1.299

# %%
name = "sweety omana"

# %%
print(f"Hello her name is {name}")
# Out:
# Hello her name is sweety omana

# %%
name = 'sweety'
age = 23
print(f"{name} is {age} year'd old.")
# Out:
# sweety is 23 year'd old.

# %% [markdown]
# ### Lists

# %%
my_list = [1,2,3,4,5]

# %%
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
len(my_list)
# Out:
# 5

# %%
my_list.append("Chandru")

# %%
my_list.append(3.14)

# %%
my_list.append(True)

# %%
my_list
# Out:
# [1, 2, 3, 4, 5, 'Chandru', 3.14, True]

# %%
ab = ['one','two','three']

# %%
cd = ['four','five']

# %%
ab + cd
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
newlst = ab + cd

# %%
newlst
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
newlst[0] = 'ONE'

# %%
newlst
# Out:
# ['ONE', 'two', 'three', 'four', 'five']

# %%
newlst.append('Six')

# %%
newlst
# Out:
# ['ONE', 'two', 'three', 'four', 'five', 'Six']

# %%
newlst.count('ONE')
# Out:
# 1

# %%
newlst.append("Seven")

# %%
newlst
# Out:
# ['ONE', 'two', 'three', 'four', 'five', 'Six', 'Seven']

# %%
newlst.pop()
# Out:
# 'Seven'

# %%
newlst
# Out:
# ['ONE', 'two', 'three', 'four', 'five', 'Six']

# %%
pop_item = newlst.pop()

# %%
pop_item
# Out:
# 'Six'

# %%
new = ['a','g','t','b','z']
num= [9,2,5,1,0]

# %%
new.sort()
new_list = new

# %%
new
# Out:
# ['a', 'b', 'g', 't', 'z']

# %%
new_list
# Out:
# ['a', 'b', 'g', 't', 'z']

# %%
num.sort()
new_num = num

# %%
num
# Out:
# [0, 1, 2, 5, 9]

# %%
new_num
# Out:
# [0, 1, 2, 5, 9]

# %%
new_num.reverse()

# %%
new_num
# Out:
# [9, 5, 2, 1, 0]

# %% [markdown]
# ### Dictionary

# %%
# key:value -- pair

# %%
# {key1:value1, key2:value2}

# %%
my_dict = {'name':'chandru','branch':'EEE','batch':2019}

# %%
my_dict
# Out:
# {'name': 'chandru', 'branch': 'EEE', 'batch': 2019}

# %%
my_dict['name']
# Out:
# 'chandru'

# %%
my_dict.keys()
# Out:
# dict_keys(['name', 'branch', 'batch'])

# %%
my_dict.values()
# Out:
# dict_values(['chandru', 'EEE', 2019])

# %%
my_dict.items()
# Out:
# dict_items([('name', 'chandru'), ('branch', 'EEE'), ('batch', 2019)])

# %%
d = {'k1':123,'k2':[0,1,2],'k3':{'inside_key':100}}

# %%
d
# Out:
# {'k1': 123, 'k2': [0, 1, 2], 'k3': {'inside_key': 100}}

# %%
d.items()
# Out:
# dict_items([('k1', 123), ('k2', [0, 1, 2]), ('k3', {'inside_key': 100})])

# %%
d['k3']['inside_key']
# Out:
# 100

# %%
dd = {'k1':['a','b','c']}

# %%
dd
# Out:
# {'k1': ['a', 'b', 'c']}

# %%
print(dd)
# Out:
# {'k1': ['a', 'b', 'c']}

# %%
lst = dd['k1']

# %%
lst
# Out:
# ['a', 'b', 'c']

# %%
lst[2].upper()
# Out:
# 'C'

# %%
c = {'k1':100,'k2':200}

# %%
d['k3'] = 200

# %%
c['k3'] = 1000

# %%
c
# Out:
# {'k1': 100, 'k2': 200, 'k3': 1000}

# %%
d
# Out:
# {'k1': 123, 'k2': [0, 1, 2], 'k3': 200}

# %% [markdown]
# ### Tuple

# %%
tup = (1,2,3,4,5)

# %%
print(tup)
# Out:
# (1, 2, 3, 4, 5)

# %%
l = [1,2]

# %%
type(tup)
type(l)
# Out:
# list

# %%
type(tup)
# Out:
# tuple

# %%
t = ('one',2,3.133)

# %%
t
# Out:
# ('one', 2, 3.133)

# %%
t[0]
# Out:
# 'one'

# %%
t[-1]
# Out:
# 3.133

# %%
t.count('one')
# Out:
# 1

# %%
t.index(3.133)
# Out:
# 2

# %%
t
# Out:
# ('one', 2, 3.133)

# %%
t = ('one', 2, 3.133,1,2,3,4,5,5,5,9)

# %%
t
# Out:
# ('one', 2, 3.133, 1, 2, 3, 4, 5, 5, 5, 9)

# %%
t[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 t[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### SET

# %%
s = {1,2,3,4,5,5}

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s.add(1)

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s = {1,2,3,4,5,6,7,8,9}

# %%
s.add(2)

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
my = [1,1,1,2,2,2,3,3,3]

# %%
set(my)
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
1<2
# Out:
# True

# %%
2>1
# Out:
# True

# %%
2>3
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
c = None

# %%
print(c)
# Out:
# None

# %% [markdown]
# ### Input/Output with basic files

# %%
# %%writefile myfile.txt
# Hello this is python programming
# hello myself chandru
# I lives in Neyveli
# Out:
# Writing myfile.txt

# %%
myfile = open('myfile.txt')

# %%
myfile = open('kathir.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 myfile = open('kathir.txt')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kathir.txt'

# %%
pwd
# Out:
# 'G:\\Chandru\\Revision'

# %%
ls
# Out:
#  Volume in drive G is Data Science & AI
#  Volume Serial Number is D0F6-BFCA
#
#  Directory of G:\Chandru\Revision
#
# 21-01-2026  16:06    <DIR>          .
# 21-01-2026  16:06    <DIR>          ..
# 21-01-2026  12:04    <DIR>          .ipynb_checkpoints
# 16-01-2026  22:24           162,824 1_Data_Preprocessing_ML.ipynb
# 21-01-2026  16:06            60,790 1-python.ipynb
# 16-01-2026  22:12           106,474 2_Simple_Linear_Regression.ipynb
# 17-01-2026  01:17            67,543 3_Multi_Linear_Regression.ipynb
# 16-01-2026  22:28             2,436 50_Startups.csv
# 21-01-2026  16:06                76 myfile.txt
# 16-01-2026  00:24            19,568 Python_Fundamentals.ipynb
# 15-01-2026  20:17               454 Salary_Data.csv
# 15-01-2026  20:18            35,459 simple_linear_regression.ipynb
# 16-01-2026  20:35             1,501 str.ipynb
# 15-01-2026  16:44            61,194 Titanic-Dataset.csv
#               11 File(s)        518,319 bytes
# ...

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'Hello this is python programming\nhello myself chandru\nI lives in Neyveli\n'

# %%
myfile.read()
# Out:
# ''

# %%
# %%writefile chandru.txt
# this is chandru,
# I live in USA,
# I am Ai Engineer.
# Out:
# Overwriting chandru.txt

# %%
myfile = open("chandru.txt")

# %%
myfile
# Out:
# <_io.TextIOWrapper name='chandru.txt' mode='r' encoding='cp1252'>

# %%
myfile.read()
# Out:
# 'this is chandru,\nI live in USA,\nI am Ai Engineer.\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'this is chandru,\nI live in USA,\nI am Ai Engineer.\n'

# %%
content = myfile.read()

# %%
content
# Out:
# 'this is chandru,\nI live in USA,\nI am Ai Engineer.\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['this is chandru,\n', 'I live in USA,\n', 'I am Ai Engineer.\n']

# %% [markdown]
# #### file locations

# %%
pwd
# Out:
# 'G:\\Chandru\\Revision'

# %%
myfile.close()

# %%
with open("myfile.txt",mode='r') as cmd:
    cont = cmd.read()

# %%
cont
# Out:
# 'Hello this is python programming\nhello myself chandru\nI lives in Neyveli\n'

# %%
with open(r"F:\kathiravan.txt",mode='r') as kmd:
    contd = kmd.readlines()

# %%
contd
# Out:
# ['Software Engineer']

# %%
cont
# Out:
# 'Hello this is python programming\nhello myself chandru\nI lives in Neyveli\n'

# %%
# %%writefile sweety.txt
# sweety
# omana
# malayali
# girl.
# Out:
# Writing sweety.txt

# %%
with open("sweety.txt",mode='r+') as so:
    print(so.readlines())
    print(so.read())
# Out:
# ['sweety\n', 'omana\n', 'malayali\n', 'girl.\n']

# %%
with open("sweety.txt",mode='a') as a:
    a.write("Kerala")
    a.write("Lives in coimbatore")

# %%
with open("sweety.txt",mode='r+') as a:
    #a.write("Kerala")
    #a.write("Lives in coimbatore")
    print(a.read())
# Out:
# sweety
# omana
# malayali
# girl.
# KeralaLives in coimbatore
